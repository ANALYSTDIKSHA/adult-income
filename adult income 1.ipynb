# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("adult.csv")

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.tail()
# Out:
#        age     workclass  fnlwgt   education  educational-num  \
# 48837   27       Private  257302  Assoc-acdm               12
# 48838   40       Private  154374     HS-grad                9
# 48839   58       Private  151910     HS-grad                9
# 48840   22       Private  201490     HS-grad                9
# 48841   52  Self-emp-inc  287927     HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48837             0             0              38  United-States  <=50K
# ...

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
# Fetching 30% random samples from the dataset


df.sample(frac=0.3)
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 1835    22    Private  146352       HS-grad                9
# 23408   25    Private  235795    Assoc-acdm               12
# 37350   23    Private  283796          12th                8
# 7274    50    Private  106422       HS-grad                9
# 40199   28          ?  131310          12th                8
# ...    ...        ...     ...           ...              ...
# 13952   19    Private   57366  Some-college               10
# 39967   40    Private  199599          10th                6
# 34763   29  Local-gov  376302     Assoc-voc               11
# 47010   31  Local-gov  224234       HS-grad                9
# 8508    58    Private  177368       HS-grad                9
#
#            marital-status         occupation    relationship   race  gender  \
# 1835        Never-married              Sales       Unmarried  White  Female
# 23408       Never-married              Sales   Not-in-family  White    Male
# ...

# %%
# check null values

df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
# replace "?" with nan


df= pd.read_csv("adult.csv" , na_values= "?")

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# % of values having null in each column

df.isnull().sum()*100/len(df)
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
df.dropna(how="any",inplace=True)

# %%
# to check duplicated data 


df[df.duplicated()]
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 864     24           Private  194630     Bachelors               13
# 11189   37           Private   52870     Bachelors               13
# 11212   29           Private   36440     Bachelors               13
# 13848   30           Private  180317     Assoc-voc               11
# 15960   18      Self-emp-inc  378036          12th                8
# 18476   39           Private  184659       HS-grad                9
# 19399   19           Private  130431       5th-6th                3
# 19726   41           Private  116391     Bachelors               13
# 20606   25           Private  308144     Bachelors               13
# 21162   25           Private  308144     Bachelors               13
# 21385   90           Private   52386  Some-college               10
# 24361   21           Private  243368     Preschool                1
# 25452   21           Private  250051  Some-college               10
# ...

# %%
df.shape
# Out:
# (45222, 15)

# %%
# dropping the duplicated data

df =df.drop_duplicates()
df.shape
# Out:
# (45175, 15)

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  45175.000000  4.517500e+04     45175.000000  45175.000000
# mean      38.556170  1.897388e+05        10.119314   1102.576270
# std       13.215349  1.056524e+05         2.551740   7510.249876
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.173925e+05         9.000000      0.000000
# 50%       37.000000  1.783120e+05        10.000000      0.000000
# 75%       47.000000  2.379030e+05        13.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  45175.000000    45175.000000
# mean      88.687593       40.942512
# std      405.156611       12.007730
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
# dropping 2 columns but not in original dataframe

df.drop(['fnlwgt','capital-gain'] ,axis =1)
# Out:
#        age     workclass     education  educational-num      marital-status  \
# 0       25       Private          11th                7       Never-married
# 1       38       Private       HS-grad                9  Married-civ-spouse
# 2       28     Local-gov    Assoc-acdm               12  Married-civ-spouse
# 3       44       Private  Some-college               10  Married-civ-spouse
# 5       34       Private          10th                6       Never-married
# ...    ...           ...           ...              ...                 ...
# 48837   27       Private    Assoc-acdm               12  Married-civ-spouse
# 48838   40       Private       HS-grad                9  Married-civ-spouse
# 48839   58       Private       HS-grad                9             Widowed
# 48840   22       Private       HS-grad                9       Never-married
# 48841   52  Self-emp-inc       HS-grad                9  Married-civ-spouse
#
# ...

# %%
# Get Overall Statistics About The Dataframe


df.describe(include = "all")
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   45175.000000     45175  4.517500e+04     45175     45175.000000
# unique           NaN         7           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33262           NaN     14770              NaN
# mean       38.556170       NaN  1.897388e+05       NaN        10.119314
# std        13.215349       NaN  1.056524e+05       NaN         2.551740
# min        17.000000       NaN  1.349200e+04       NaN         1.000000
# 25%        28.000000       NaN  1.173925e+05       NaN         9.000000
# 50%        37.000000       NaN  1.783120e+05       NaN        10.000000
# 75%        47.000000       NaN  2.379030e+05       NaN        13.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status    occupation relationship   race gender  \
# ...

# %%
# Counting unique values race column is having


df['race'].value_counts()
# Out:
# White                 38859
# Black                  4227
# Asian-Pac-Islander     1301
# Amer-Indian-Eskimo      435
# Other                   353
# Name: race, dtype: int64

# %%
# just showing all the unique values of race column

df['race'].unique()
# Out:
# array(['Black', 'White', 'Other', 'Amer-Indian-Eskimo',
#        'Asian-Pac-Islander'], dtype=object)

# %%
# dropping capital-gain and capital-loss columnn as we can see 75% values are 0 in it

df.drop(['capital-gain','capital-loss'],inplace=True,axis =1)
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 5   34    Private  198693          10th                6       Never-married
#
#           occupation   relationship   race gender  hours-per-week  \
# 0  Machine-op-inspct      Own-child  Black   Male              40
# 1    Farming-fishing        Husband  White   Male              50
# 2    Protective-serv        Husband  White   Male              40
# 3  Machine-op-inspct        Husband  Black   Male              40
# 5      Other-service  Not-in-family  White   Male              30
#
#   native-country income
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States   >50K
# ...

# %%
# Checking and dropping the remaining duplicate data


df[df.duplicated()]
df=df.drop_duplicates()

# %%
# now dataset having no duplicate data

df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, educational-num, marital-status, occupation, relationship, race, gender, hours-per-week, native-country, income]
# Index: []

# %%
df['age'].unique()
# Out:
# array([25, 38, 28, 44, 34, 63, 24, 55, 65, 36, 26, 48, 43, 20, 37, 45, 22,
#        23, 54, 32, 46, 56, 17, 29, 39, 52, 18, 21, 42, 33, 30, 47, 41, 19,
#        69, 50, 31, 59, 49, 58, 40, 27, 57, 61, 51, 73, 53, 80, 62, 35, 72,
#        64, 68, 66, 60, 67, 71, 70, 90, 77, 81, 74, 78, 82, 75, 85, 76, 89,
#        83, 79, 88, 87, 84, 86], dtype=int64)

# %%
# Showing age dist and its frequency

plt.xlabel("age")
plt.ylabel("frequency of age")
plt.hist(df['age'] ,bins =5)
#,log=True
# Out:
# (array([15501., 17498.,  9321.,  2579.,   268.]),
#  array([17. , 31.6, 46.2, 60.8, 75.4, 90. ]),
#  <BarContainer object of 5 artists>)

# %%
sns.kdeplot(df['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
# no. of people between 17 & 48 age without between method

df[(df['age'] >=17) & (df['age'] <=48)].count()
# Out:
# age                34851
# workclass          34851
# fnlwgt             34851
# education          34851
# educational-num    34851
# marital-status     34851
# occupation         34851
# relationship       34851
# race               34851
# gender             34851
# hours-per-week     34851
# native-country     34851
# income             34851
# dtype: int64

# %%
# showing no. of people earning between 30-40 hrs o

df[df['hours-per-week'].between(30,40)].count()
# Out:
# age                26342
# workclass          26342
# fnlwgt             26342
# education          26342
# educational-num    26342
# marital-status     26342
# occupation         26342
# relationship       26342
# race               26342
# gender             26342
# hours-per-week     26342
# native-country     26342
# income             26342
# dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.hist(df['workclass'])
# Out:
# (array([3.3255e+04, 3.1000e+03, 0.0000e+00, 3.7940e+03, 0.0000e+00,
#         1.4060e+03, 1.9460e+03, 0.0000e+00, 1.6450e+03, 2.1000e+01]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
df['education'].unique()
# Out:
# array(['11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th',
#        'Prof-school', '7th-8th', 'Bachelors', 'Masters', '5th-6th',
#        'Assoc-voc', '9th', 'Doctorate', '12th', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
# people having bachelors or masters degree


df[(df['education'] == 'Bachelors') | (df['education'] == 'Masters')]
# Out:
#        age    workclass  fnlwgt  education  educational-num  \
# 11      36  Federal-gov  212465  Bachelors               13
# 15      43      Private  346189    Masters               14
# 20      34      Private  107914  Bachelors               13
# 23      25      Private  220931  Bachelors               13
# 24      25      Private  205947  Bachelors               13
# ...    ...          ...     ...        ...              ...
# 48817   34      Private  160216  Bachelors               13
# 48819   38      Private  139180  Bachelors               13
# 48825   31      Private  199655    Masters               14
# 48834   32      Private  116138    Masters               14
# 48835   53      Private  321865    Masters               14
#
#            marital-status       occupation   relationship                race  \
# 11     Married-civ-spouse     Adm-clerical        Husband               White
# 15     Married-civ-spouse  Exec-managerial        Husband               White
# ...

# %%
# people having bachelors or masters degree using str.contains()

df[df['education'].str.contains('Bachelors|Masters' ,case = False)]
# Out:
#        age    workclass  fnlwgt  education  educational-num  \
# 11      36  Federal-gov  212465  Bachelors               13
# 15      43      Private  346189    Masters               14
# 20      34      Private  107914  Bachelors               13
# 23      25      Private  220931  Bachelors               13
# 24      25      Private  205947  Bachelors               13
# ...    ...          ...     ...        ...              ...
# 48817   34      Private  160216  Bachelors               13
# 48819   38      Private  139180  Bachelors               13
# 48825   31      Private  199655    Masters               14
# 48834   32      Private  116138    Masters               14
# 48835   53      Private  321865    Masters               14
#
#            marital-status       occupation   relationship                race  \
# 11     Married-civ-spouse     Adm-clerical        Husband               White
# 15     Married-civ-spouse  Exec-managerial        Husband               White
# ...

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
# countplot of income

# %%
df["income"].replace({
    "<=50K" : 0,
    ">50K" : 1
},inplace=True)
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 5   34    Private  198693          10th                6       Never-married
#
#           occupation   relationship   race gender  hours-per-week  \
# 0  Machine-op-inspct      Own-child  Black   Male              40
# 1    Farming-fishing        Husband  White   Male              50
# 2    Protective-serv        Husband  White   Male              40
# 3  Machine-op-inspct        Husband  Black   Male              40
# 5      Other-service  Not-in-family  White   Male              30
#
#   native-country  income
# 0  United-States       0
# 1  United-States       0
# 2  United-States       1
# ...

# %%
df.groupby('workclass')['hours-per-week'].min()
# Out:
# workclass
# Federal-gov          4
# Local-gov            2
# Private              1
# Self-emp-inc         4
# Self-emp-not-inc     1
# State-gov            1
# Without-pay         10
# Name: hours-per-week, dtype: int64

# %%
df.groupby('gender')['income'].mean()
# Out:
# gender
# Female    0.113700
# Male      0.312615
# Name: income, dtype: float64
